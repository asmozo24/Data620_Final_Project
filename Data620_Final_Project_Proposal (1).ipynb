# %% [markdown]
# ####     The City University of New York School of Professional Studies (CUNY-SPS)
# ####     Web Analytics DATA 620
#
# ##       Final Project Proposal: Using Sentiment Analysis to reduce interview stress on Job Seekers
#
#
#
# #####    Alexis Mekueko
#
#
# Github Link –> https://github.com/asmozo24/Data620_Final_Project_Proposal
#
# ###  Project Description
#
# #### Background
#
# Interviews can be a nightmare for job seekers. Many companies use interviews to select the best candidate to fulfill a position.
# Interview is a verbal communication with the purpose to assess the candidate's skills in relevance to the job description.
# Since it is a selection process, candidates are outto to know the job description well. Indeed, there are many studies[1,2] that have shown the effect of interview
# stress on a job candidate performance. Hence, there is an opportunity for data scientist/analyst to explore solution that
# will discrease the stress among job seekers over interviews. Therefore understanding well the job description is a step to deliver the best of oneself.
#
#
# #### Research Questions
#
# How can we use sentiment analysis to help job seekers to better understand job description?
#
#
# #### Overall Workflow
#
# We will use OSEMN Process:
#
# 1.  Obtaining Data
#     - Unstructured Data
#     - Github
#     -Jupyter Notebook-Python
# 2.  Scrubing Data
#     - organizing data
#     - Tidying up data
# 3.  Explore Data
#     - Inspect data and understand the characteristic of the data
#     - Looking for relationship, patterns and values,
# 4.  Modeling Data
#     - Natural Language Processing/Sentiment Analysis
#     - Explore other data visualization charts
# 5.  Interpret Results
#     - Explaining findings (Answering the research question)
#     - Actionable information
#
#
# #### Data Sources
#
# We will explore the following sites to collect the data needed for this project:
#
# job descriptions - indeed.com
#                  - monster.com
#                  - linkedIn.com.
#
# Germany v Brazil | 2002 FIFA World Cup Final - https://www.youtube.com/fifa
# 2022 CUNY SPS Commencement Ceremony - https://www.youtube.com/user/CUNYSPS
#
#
# #### Challenges
#
# There are few challenges in this project to be overcome:
#
# 1. data source: In this project, We will use collected data available online through popular job sites. This will be a collections of data. It is going to be tidious a little bit. An alternate solution is to copy
#     the link where the job descriotion is but other information not related to the job description will add biais to the work.
#
# 2. Understanding how sentiment analysis work in order to answer the research questions can be difficult.
#
# 3. Interpreting Results: This is going to be crucial. How to present the result, wouldn't it be better to have the results in
#     summary ?
#
# 4. Bonuses: we want to explore the sentiment analysis on recorded video. We will use the "2022 CUNY SPS Commencement Ceremony" and
#     "Germany v Brazil | 2002 FIFA World Cup Final". We are curious about the findings on such data.
#
# #### Benefits
#
# This project will help job seekers to better understand the job description. Ultimately, this project could potentially lead to
# an apps that any job seeker could use on job description. This will be done by simply copy the link of the job description and
# paste onto the apps and get resluts.
#
#
# #### References
#
# 1. Johnson, Dale T. , "Effects of interview stress on measure of state and trait anxiety.", https://psycnet.apa.org/record/1968-12163-001
#
# 2. Mahnaz Behroozi, Shivani Shirolkar, Titus Barik, Chris Parnin, "Does stress impact technical interview performance?", https://dl.acm.org/doi/abs/10.1145/3368089.3409712
